# %%
# Importando as bibliotecas
import sqlite3
import requests
from datetime import datetime

# Conexão com o banco de dados
conn = sqlite3.connect('/home/marcus/Python/controle_pagamentos/src/data/pagamentos.db')
cursor = conn.cursor()

# Função para listar pagamentos
def listar_pagamentos():
    cursor.execute('SELECT * FROM pagamentos')
    pagamentos = cursor.fetchall()
    if pagamentos:
        for pagamento in pagamentos:
            print(pagamento)
    else:
        print("Nenhum pagamento cadastrado.")

listar_pagamentos()
# Out:
# (1, 'Compra AWS', 'USD', 50.0, 282.7492, '2025-04-30')
# (2, 'Curso online', 'EUR', 30.0, 192.92589, '2025-04-30')
# (3, 'Jogo', 'USD', 50.0, 282.7492, '2025-04-30')
# (4, 'Ingresso Cinema', 'USD', 10.0, 56.549839999999996, '2025-04-30')
